# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\Users\hemak\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\hemak\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\hemak\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\hemak\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\hemak\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in c:\Users\hemak\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in C:\Users\hemak\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.1)
# Requirement already satisfied: pillow>=8 in c:\Users\hemak\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\hemak\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\hemak\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\hemak\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
months  = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'] # X axis in chart 
sales   = [120, 135, 148, 162, 190, 175, 210, 225, 198, 240, 268, 310] # line
targets = [130, 140, 155, 165, 180, 190, 205, 215, 220, 235, 255, 290] # line
# 100, 200, 300

fig, ax = plt.subplots(figsize=(11,5))
ax.plot(months, sales, color='#2196F3', linewidth=2.5, marker='o',
        markersize=7, label='Actual Sales') # Sales

ax.plot(months, targets, color='#FF5722', linewidth=2, linestyle='--',
marker='s', markersize=6, label='Target') # Targert


ax.fill_between(months, sales, alpha=0.10, color='#2196F3')

ax.set_title('Monthly Sales Performance 2026', fontsize=15, fontweight='bold', pad=15)
ax.set_xlabel('Month', fontsize=12)
ax.set_ylabel('Sales (Units)', fontsize=12)
ax.legend(fontsize=11)
plt.tight_layout()
plt.show()

# %%
# Bar chart (Sales, ranking )

plt.bar([10,20,30], [15,25,35])
plt.show()

# %%
# Scatter chart (More or lot of the data - we can use)

plt.scatter([1,2,3], [5,6,7])
plt.show()

# %%
# Horizontal Chart

import matplotlib.pyplot as plt

products = ['Laptop Pro', 'Wireless Earbuds', 'Smart Watch', 'Tablet Mini',
            'USB-C Hub', 'Mechanical Keyboard', 'Webcam HD', 'Mouse Ergonomic']
units_sold = [4820, 7310, 5940, 3200, 6450, 2980, 4100, 5670]

# Sort descending
sorted_pairs = sorted(zip(units_sold, products))
units_sorted, prods_sorted = zip(*sorted_pairs)

colors = ['#EF5350' if u > 6000 else '#42A5F5' if u > 4500 else '#78909C'
          for u in units_sorted]

fig, ax = plt.subplots(figsize=(10, 6))
bars = ax.barh(prods_sorted, units_sorted, color=colors, edgecolor='white', height=0.6)

for bar, val in zip(bars, units_sorted):
    ax.text(val + 50, bar.get_y() + bar.get_height()/2,
            f'{val:,}', va='center', fontsize=10, fontweight='bold')

ax.set_title('Product Sales Ranking', fontsize=14, fontweight='bold', pad=12)
ax.set_xlabel('Units Sold', fontsize=12)
ax.axvline(x=5000, color='orange', linestyle='--', linewidth=1.5, label='Target: 5,000')
ax.legend(fontsize=10)
ax.grid(axis='x', linestyle='--', alpha=0.4)
ax.set_xlim(0, max(units_sorted) * 1.15)
plt.tight_layout()
plt.show()
print("Red bars = above 6,000 units | Blue = above 4,500 | Grey = below 4,500")
# Out:
# Red bars = above 6,000 units | Blue = above 4,500 | Grey = below 4,500

# %%
# Unit Sorted (Already sold units are in different location

for bar, val in zip(bars, units_sorted):
    print(val + 50, bar.get_y() + bar.get_height()/2)
    ax.text(val + 50, bar.get_y() + bar.get_height()/2,
            f'{val:,}', va='center', fontsize=10, fontweight='bold')
# Out:
# 3030 0.0
# 3250 1.0
# 4150 2.0
# 4870 3.0
# 5720 4.0
# 5990 5.0
# 6500 6.0
# 7360 7.0

# %%
# Pie chart

labels  = ['Samsung', 'Apple', 'Xiaomi', 'OPPO', 'Vivo', 'Others']
sizes   = [21.6, 17.3, 12.8, 10.2, 8.9, 29.2]
explode = (0, 0.20, 0, 0, 0, 0)   # explode Apple slice
colors  = ['#1565C0','#B71C1C','#E65100','#4CAF50','#7B1FA2','#78909C']

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Left: Standard pie
axes[0].pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140,
            explode=explode, colors=colors, pctdistance=0.82,
            wedgeprops={'edgecolor':'white','linewidth':2})
axes[0].set_title('Smartphone Market Share Q1 2024\n(Standard Pie)', fontsize=12, fontweight='bold')

# Donut chart 

axes[1].pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140,
            explode=explode, colors=colors, pctdistance=0.82,
            wedgeprops={'edgecolor':'white','linewidth':2, 'width':0.5})
axes[1].text(0, 0, 'Market\nShare', ha='center', va='center', fontsize=12, fontweight='bold')
axes[1].set_title('Smartphone Market Share Q1 2024\n(Donut Chart)', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.show()
