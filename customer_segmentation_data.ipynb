# %%
import pandas as pd

# %%
df = pd.read_csv('customer_segmentation_data.csv')
df.head()
# Out:
#    CustomerID  Age  Annual_Income  Spending_Score
# 0           1   56          28392              19
# 1           2   46          50535              20
# 2           3   32          98603              96
# 3           4   25          72256              71
# 4           5   38          55222              52

# %%
from sklearn.cluster import KMeans

X = df[['Annual_Income', 'Spending_Score']]

# %%
model = KMeans(n_clusters=5, random_state=42)

# %%
df['Cluster'] = model.fit_predict(X)

# %%
df.head(20)
# Out:
#     CustomerID  Age  Annual_Income  Spending_Score  Cluster
# 0            1   56          28392              19        3
# 1            2   46          50535              20        1
# 2            3   32          98603              96        2
# 3            4   25          72256              71        0
# 4            5   38          55222              52        1
# 5            6   56          97373              33        2
# 6            7   36          99575              40        2
# 7            8   40          83335              39        4
# 8            9   28          30965              82        3
# 9           10   28          44538               1        1
# 10          11   41          90592              11        4
# 11          12   53          28110              92        3
# 12          13   57          99309              57        2
# 13          14   41          47266              89        1
# 14          15   20          72992              50        0
# 15          16   39          26910              23        3
# 16          17   19          20206              31        3
# 17          18   41          43419              94        1
# 18          19   47          70636              42        0
# 19          20   55          70015              99        0

# %%
import matplotlib as plt

# %%
model.cluster_centers_
# Out:
# array([[6.96173448e+04, 4.35172414e+01],
#        [4.67786154e+04, 4.73846154e+01],
#        [9.59553333e+04, 6.02222222e+01],
#        [2.77358235e+04, 4.83529412e+01],
#        [8.53502632e+04, 4.27894737e+01]])

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Annual_Income'], df['Spending_Score'], c=df['Cluster'])

# Plot centroids
centroids = model.cluster_centers_
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='X')

plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.title('Customer Segmentation')

plt.show()
