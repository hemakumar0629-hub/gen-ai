# %% [markdown]
# # Unsupervised Learning - Customer Segmentation
# Using K-Means to group customers.

# %%
import pandas as pd

df = pd.read_csv('customer_segmentation_data.csv')
df.head()
# Out:
#    CustomerID  Age  Annual_Income  Spending_Score
# 0           1   56          28392              19
# 1           2   46          50535              20
# 2           3   32          98603              96
# 3           4   25          72256              71
# 4           5   38          55222              52

# %%
from sklearn.cluster import KMeans

# %%
X = df[['Annual_Income', 'Spending_Score']]
print(X.head())
# Out:
#    Annual_Income  Spending_Score
# 0          28392              19
# 1          50535              20
# 2          98603              96
# 3          72256              71
# 4          55222              52

# %%
model = KMeans(n_clusters=5, random_state=42)

# %%
df['Cluster'] = model.fit_predict(X)
print(df.head())
# Out:
#    CustomerID  Age  Annual_Income  Spending_Score  Cluster
# 0           1   56          28392              19        3
# 1           2   46          50535              20        1
# 2           3   32          98603              96        2
# 3           4   25          72256              71        0
# 4           5   38          55222              52        1

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Annual_Income'], df['Spending_Score'], c=df['Cluster'])
plt.scatter(model.cluster_centers_[:, 0],
            model.cluster_centers_[:, 1],
            color='red', marker='X', s=200)  # centroids
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.show()

print(df.head())
# Out:
#    CustomerID  Age  Annual_Income  Spending_Score  Cluster
# 0           1   56          28392              19        3
# 1           2   46          50535              20        1
# 2           3   32          98603              96        2
# 3           4   25          72256              71        0
# 4           5   38          55222              52        1

# %% [markdown]
# ## Train Model

# %%
from sklearn.cluster import KMeans

X = df[['Annual_Income', 'Spending_Score']]
model = KMeans(n_clusters=5, random_state=42)
df['Cluster'] = model.fit_predict(X)
df.head()
# Out:
#    CustomerID  Age  Annual_Income  Spending_Score  Cluster
# 0           1   56          28392              19        3
# 1           2   46          50535              20        1
# 2           3   32          98603              96        2
# 3           4   25          72256              71        0
# 4           5   38          55222              52        1

# %% [markdown]
# ## View Clusters

# %%
df.groupby('Cluster').mean()
# Out:
#          CustomerID        Age  Annual_Income  Spending_Score
# Cluster
# 0         55.000000  40.310345   69617.344828       43.517241
# 1         50.384615  35.307692   46778.615385       47.384615
# 2         31.555556  45.222222   95955.333333       60.222222
# 3         49.117647  36.941176   27735.823529       48.352941
# 4         54.000000  35.210526   85350.263158       42.789474

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Annual_Income'], df['Spending_Score'], c=df['Cluster'])
plt.xlabel('Income')
plt.ylabel('Spending Score')
plt.title('Customer Segments')
plt.show()
